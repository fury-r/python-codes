# %%
import pandas as pd
pd.read_csv("./datasets/players_20.csv")
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
import pandas as pd
dataframe=pd.read_csv("./datasets/players_20.csv")
dataframe.shape
# Out:
# (18278, 104)

# %%
dataframe.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
dataframe.values
# Out:
# array([[158023,
#         'https://sofifa.com/player/158023/lionel-messi/20/159586',
#         'L. Messi', ..., '52+2', '52+2', '63+2'],
#        [20801,
#         'https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/20/159586',
#         'Cristiano Ronaldo', ..., '53+3', '53+3', '61+3'],
#        [190871,
#         'https://sofifa.com/player/190871/neymar-da-silva-santos-jr/20/159586',
#         'Neymar Jr', ..., '46+3', '46+3', '61+3'],
#        ...,
#        [252332, 'https://sofifa.com/player/252332/wei-zhang/20/159586',
#         'Zhang Wei', ..., '49+2', '49+2', '47+2'],
#        [251110,
#         'https://sofifa.com/player/251110/haijian-wang/20/159586',
#         'Wang Haijian', ..., '49+2', '49+2', '48+2'],
#        [233449, 'https://sofifa.com/player/233449/ximing-pan/20/159586',
#         'Pan Ximing', ..., '50+2', '50+2', '48+2']], dtype=object)

# %%
dataframe[dataframe['short_name']>'Cristanio'].head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
dataframe.sort_values(col1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b8579555417e> in <module>
# ----> 1 dataframe.sort_values(col1)
#
# NameError: name 'dataframe' is not defined

# %%
import pandas as pd
dataframe=pd.read_csv("./datasets/players_20.csv")

# %%
dataframe.sort_values(col1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b8579555417e> in <module>
# ----> 1 dataframe.sort_values(col1)
#
# NameError: name 'dataframe' is not defined

# %%
dataframe.sort_values(col1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b8579555417e> in <module>
# ----> 1 dataframe.sort_values(col1)
#
# NameError: name 'col1' is not defined

# %%
dataframe.columns=['a','b','c','d']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-6715982b2ff5> in <module>
# ----> 1 dataframe.columns=['a','b','c','d']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# ...

# %%
dataframe['player_url']
# Out:
# 0        https://sofifa.com/player/158023/lionel-messi/...
# 1        https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2        https://sofifa.com/player/190871/neymar-da-sil...
# 3        https://sofifa.com/player/200389/jan-oblak/20/...
# 4        https://sofifa.com/player/183277/eden-hazard/2...
#                                ...
# 18273    https://sofifa.com/player/245006/shuai-shao/20...
# 18274    https://sofifa.com/player/250995/mingjie-xiao/...
# 18275    https://sofifa.com/player/252332/wei-zhang/20/...
# 18276    https://sofifa.com/player/251110/haijian-wang/...
# 18277    https://sofifa.com/player/233449/ximing-pan/20...
# Name: player_url, Length: 18278, dtype: object

# %%
dataframe[dataframe['dob'] >= '1999-20-12']
# Out:
#        sofifa_id                                         player_url  \
# 108       233049  https://sofifa.com/player/233049/jadon-sancho/...
# 568       238794  https://sofifa.com/player/238794/vinicius-jose...
# 1254      237692  https://sofifa.com/player/237692/phil-foden/20...
# 1255      236610  https://sofifa.com/player/236610/moise-kean/20...
# 1256      243812  https://sofifa.com/player/243812/rodrygo-silva...
# ...          ...                                                ...
# 18267     247002  https://sofifa.com/player/247002/jack-ryan/20/...
# 18268     247452  https://sofifa.com/player/247452/michael-galla...
# 18269     252181  https://sofifa.com/player/252181/jiahui-huang/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
#
#          short_name                         long_name  age         dob  \
# 108       J. Sancho                      Jadon Sancho   19  2000-03-25
# ...

# %%
dataframe.dropna(axis=1)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
x="Null"
dataframe.fillna(x)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
dataframe.apply(np.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f631c248f800> in <module>
# ----> 1 dataframe.apply(np.mean())
#
# NameError: name 'np' is not defined

# %%
dataframe.pivot_table(index='sofifa_id', values= ['age','height_cm' ], aggfunc='mean')
# Out:
#            age  height_cm
# sofifa_id
# 768         34        188
# 1179        41        192
# 2147        36        197
# 2335        39        191
# 2702        40        180
# ...        ...        ...
# 252900      25        193
# 252901      19        174
# 252903      18        175
# 252904      22        182
# 252905      18        188
#
# [18278 rows x 2 columns]

# %%
import statistics

# %%
dataframe.pivot_table(index='sofifa_id', values= ['age','height_cm' ], aggfunc=statistics.mean)
# Out:
#            age  height_cm
# sofifa_id
# 768         34        188
# 1179        41        192
# 2147        36        197
# 2335        39        191
# 2702        40        180
# ...        ...        ...
# 252900      25        193
# 252901      19        174
# 252903      18        175
# 252904      22        182
# 252905      18        188
#
# [18278 rows x 2 columns]

# %%
df=dataframe
df.groupby('age')

# %%
df.groupby('age')

# %%
df.read_csv()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-f598ed146bb0> in <module>
# ----> 1 df.read_csv()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
dataframe
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
import numpy as np
dataframe.apply(np.mean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1536         try:
# -> 1537             x = float(x)
#    1538         except ValueError:
#
# ...

# %%
dataframe.quality
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-804434978616> in <module>
# ----> 1 dataframe.quality
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'quality'

# %%
dataframe=pd.read_csv("./datasets/players_20.csv",sep=';')
dataframe.shape
# Out:
# (18278, 1)

# %%
dataframe.quality
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-804434978616> in <module>
# ----> 1 dataframe.quality
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'quality'

# %%
dataframe.quality
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-804434978616> in <module>
# ----> 1 dataframe.quality
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'quality'

# %%
dataframe.quality
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-804434978616> in <module>
# ----> 1 dataframe.quality
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'quality'

# %%
y = dataframe.quality
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-9da908734865> in <module>
# ----> 1 y = dataframe.quality
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'quality'

# %%
dataframe.drop('age')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-52361d8fcf5f> in <module>
# ----> 1 dataframe.drop('age')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9da2ca430050> in <module>
# ----> 1 dataframe
#
# NameError: name 'dataframe' is not defined

# %%
import pandas as pd
df=pd.read_csv("./datasets/data.csv")
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df['Wage']
# Out:
# 0        €565K
# 1        €405K
# 2        €290K
# 3        €260K
# 4        €355K
#          ...
# 18202      €1K
# 18203      €1K
# 18204      €1K
# 18205      €1K
# 18206      €1K
# Name: Wage, Length: 18207, dtype: object

# %%
df.groupby(['Name','Wage','Value'])

# %%
a=df.groupby(['Name','Wage','Value'])
print(a)

# %%
print(a.describe)
# Out:
# <bound method GroupBy.describe of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001FF7A5DF5B0>>

# %%
a.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-d74f1bcdd37c> in <module>
# ----> 1 a.shape
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'shape'

# %%
df1=pd.DataFrame(df,columns=['Name','Wage','Value'])
df1
# Out:
#                      Name   Wage    Value
# 0                L. Messi  €565K  €110.5M
# 1       Cristiano Ronaldo  €405K     €77M
# 2               Neymar Jr  €290K  €118.5M
# 3                  De Gea  €260K     €72M
# 4            K. De Bruyne  €355K    €102M
# ...                   ...    ...      ...
# 18202        J. Lundstram    €1K     €60K
# 18203  N. Christoffersson    €1K     €60K
# 18204           B. Worman    €1K     €60K
# 18205      D. Walker-Rice    €1K     €60K
# 18206           G. Nugent    €1K     €60K
#
# [18207 rows x 3 columns]

# %%
df1.sort_values("Value",ascending=False)
# Out:
#                     Name  Wage Value
# 1903        M. Gaćinović  €26K   €9M
# 1787           Joelinton  €25K   €9M
# 1584   Lucas Evangelista  €21K   €9M
# 2054          O. Kharbin  €33K   €9M
# 108                 Pepe  €57K   €9M
# ...                  ...   ...   ...
# 8061          S. Gbohouo    €0    €0
# 8057        D. Mendiseca    €0    €0
# 3550         S. Nakamura   €4K    €0
# 3562           B. Méndez    €0    €0
# 17726          T. Warner   €1K    €0
#
# [18207 rows x 3 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
        if len(x)>1:
            return float(x.replace('B',''))*100000000
        return 0.0
wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace(r'[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1
# Out:
#                      Name      Wage        Value  market_wage_diff
# 0                L. Messi  565000.0  110500000.0       109935000.0
# 1       Cristiano Ronaldo  405000.0   77000000.0        76595000.0
# 2               Neymar Jr  290000.0  118500000.0       118210000.0
# 3                  De Gea  260000.0   72000000.0        71740000.0
# 4            K. De Bruyne  355000.0  102000000.0       101645000.0
# ...                   ...       ...          ...               ...
# 18202        J. Lundstram    1000.0      60000.0           59000.0
# 18203  N. Christoffersson    1000.0      60000.0           59000.0
# 18204           B. Worman    1000.0      60000.0           59000.0
# 18205      D. Walker-Rice    1000.0      60000.0           59000.0
# 18206           G. Nugent    1000.0      60000.0           59000.0
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
        if len(x)>1:
            return float(x.replace('B',''))*100000000
        return 0.0
wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace(r'[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1
# Out:
#                      Name      Wage        Value  market_wage_diff
# 0                L. Messi  565000.0  110500000.0       109935000.0
# 1       Cristiano Ronaldo  405000.0   77000000.0        76595000.0
# 2               Neymar Jr  290000.0  118500000.0       118210000.0
# 3                  De Gea  260000.0   72000000.0        71740000.0
# 4            K. De Bruyne  355000.0  102000000.0       101645000.0
# ...                   ...       ...          ...               ...
# 18202        J. Lundstram    1000.0      60000.0           59000.0
# 18203  N. Christoffersson    1000.0      60000.0           59000.0
# 18204           B. Worman    1000.0      60000.0           59000.0
# 18205      D. Walker-Rice    1000.0      60000.0           59000.0
# 18206           G. Nugent    1000.0      60000.0           59000.0
#
# [18207 rows x 4 columns]

# %%
df1.sort_values('market_wage_diff')
# Out:
#                    Name    Wage    Value  market_wage_diff
# 17657        J. McCombe  2000.0  10000.0            8000.0
# 14759          Yang Jun  2000.0  10000.0            8000.0
# 16628  K. Stamatopoulos  1000.0  10000.0            9000.0
# 16565       K. Kitamoto  1000.0  10000.0            9000.0
# 16310          C. Weale  1000.0  10000.0            9000.0
# ...                 ...     ...      ...               ...
# 17539          C. Singh     NaN      NaN               NaN
# 17672          R. Kawai  1000.0      NaN               NaN
# 17726         T. Warner  1000.0      NaN               NaN
# 17752       S. Phillips  1000.0      NaN               NaN
# 18183     K. Pilkington  1000.0      NaN               NaN
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
        if len(x)>1:
            return float(x.replace('B',''))*100000000
        return 0.0
    if '0'==x:
        return int(x)
wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1
# Out:
#                      Name      Wage        Value  market_wage_diff
# 0                L. Messi  565000.0  110500000.0       109935000.0
# 1       Cristiano Ronaldo  405000.0   77000000.0        76595000.0
# 2               Neymar Jr  290000.0  118500000.0       118210000.0
# 3                  De Gea  260000.0   72000000.0        71740000.0
# 4            K. De Bruyne  355000.0  102000000.0       101645000.0
# ...                   ...       ...          ...               ...
# 18202        J. Lundstram    1000.0      60000.0           59000.0
# 18203  N. Christoffersson    1000.0      60000.0           59000.0
# 18204           B. Worman    1000.0      60000.0           59000.0
# 18205      D. Walker-Rice    1000.0      60000.0           59000.0
# 18206           G. Nugent    1000.0      60000.0           59000.0
#
# [18207 rows x 4 columns]

# %%
df1.sort_values('market_wage_diff')
# Out:
#                    Name    Wage    Value  market_wage_diff
# 17657        J. McCombe  2000.0  10000.0            8000.0
# 14759          Yang Jun  2000.0  10000.0            8000.0
# 16628  K. Stamatopoulos  1000.0  10000.0            9000.0
# 16565       K. Kitamoto  1000.0  10000.0            9000.0
# 16310          C. Weale  1000.0  10000.0            9000.0
# ...                 ...     ...      ...               ...
# 17539          C. Singh     NaN      NaN               NaN
# 17672          R. Kawai  1000.0      NaN               NaN
# 17726         T. Warner  1000.0      NaN               NaN
# 17752       S. Phillips  1000.0      NaN               NaN
# 18183     K. Pilkington  1000.0      NaN               NaN
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
        if len(x)>1:
            return float(x.replace('B',''))*100000000
        return 0.0
    if '0' in x:
        print(x)
        return int(x)
wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1.sort_values('market_wage_diff')
# Out:
#                    Name    Wage    Value  market_wage_diff
# 17657        J. McCombe  2000.0  10000.0            8000.0
# 14759          Yang Jun  2000.0  10000.0            8000.0
# 16628  K. Stamatopoulos  1000.0  10000.0            9000.0
# 16565       K. Kitamoto  1000.0  10000.0            9000.0
# 16310          C. Weale  1000.0  10000.0            9000.0
# ...                 ...     ...      ...               ...
# 17539          C. Singh     NaN      NaN               NaN
# 17672          R. Kawai  1000.0      NaN               NaN
# 17726         T. Warner  1000.0      NaN               NaN
# 17752       S. Phillips  1000.0      NaN               NaN
# 18183     K. Pilkington  1000.0      NaN               NaN
#
# [18207 rows x 4 columns]

# %%
df1.sort_values('market_wage_diff')
# Out:
#                    Name    Wage    Value  market_wage_diff
# 17657        J. McCombe  2000.0  10000.0            8000.0
# 14759          Yang Jun  2000.0  10000.0            8000.0
# 16628  K. Stamatopoulos  1000.0  10000.0            9000.0
# 16565       K. Kitamoto  1000.0  10000.0            9000.0
# 16310          C. Weale  1000.0  10000.0            9000.0
# ...                 ...     ...      ...               ...
# 17539          C. Singh     NaN      NaN               NaN
# 17672          R. Kawai  1000.0      NaN               NaN
# 17726         T. Warner  1000.0      NaN               NaN
# 17752       S. Phillips  1000.0      NaN               NaN
# 18183     K. Pilkington  1000.0      NaN               NaN
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
        if len(x)>1:
            return float(x.replace('B',''))*100000000
    return 0.0

wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1.sort_values('market_wage_diff')
# Out:
#                    Name    Wage    Value  market_wage_diff
# 17657        J. McCombe  2000.0  10000.0            8000.0
# 14759          Yang Jun  2000.0  10000.0            8000.0
# 16628  K. Stamatopoulos  1000.0  10000.0            9000.0
# 16565       K. Kitamoto  1000.0  10000.0            9000.0
# 16310          C. Weale  1000.0  10000.0            9000.0
# ...                 ...     ...      ...               ...
# 17539          C. Singh     NaN      NaN               NaN
# 17672          R. Kawai  1000.0      NaN               NaN
# 17726         T. Warner  1000.0      NaN               NaN
# 17752       S. Phillips  1000.0      NaN               NaN
# 18183     K. Pilkington  1000.0      NaN               NaN
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
            return float(x.replace('B',''))*100000000
    return 0.0

wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1.sort_values('market_wage_diff')
# Out:
#                    Name    Wage    Value  market_wage_diff
# 17657        J. McCombe  2000.0  10000.0            8000.0
# 14759          Yang Jun  2000.0  10000.0            8000.0
# 16628  K. Stamatopoulos  1000.0  10000.0            9000.0
# 16565       K. Kitamoto  1000.0  10000.0            9000.0
# 16310          C. Weale  1000.0  10000.0            9000.0
# ...                 ...     ...      ...               ...
# 17539          C. Singh     NaN      NaN               NaN
# 17672          R. Kawai  1000.0      NaN               NaN
# 17726         T. Warner  1000.0      NaN               NaN
# 17752       S. Phillips  1000.0      NaN               NaN
# 18183     K. Pilkington  1000.0      NaN               NaN
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
            return float(x.replace('B',''))*100000000
    return 0.0

wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1.sort_values('market_wage_diff',ascending=False)
# Out:
#                    Name    Wage    Value  market_wage_diff
# 17657        J. McCombe  2000.0  10000.0            8000.0
# 14759          Yang Jun  2000.0  10000.0            8000.0
# 16628  K. Stamatopoulos  1000.0  10000.0            9000.0
# 16565       K. Kitamoto  1000.0  10000.0            9000.0
# 16310          C. Weale  1000.0  10000.0            9000.0
# ...                 ...     ...      ...               ...
# 17539          C. Singh     NaN      NaN               NaN
# 17672          R. Kawai  1000.0      NaN               NaN
# 17726         T. Warner  1000.0      NaN               NaN
# 17752       S. Phillips  1000.0      NaN               NaN
# 18183     K. Pilkington  1000.0      NaN               NaN
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
            return float(x.replace('B',''))*10000000
    else:
        return 0.0

wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1.sort_values('market_wage_diff',ascending=False)
# Out:
#                 Name      Wage        Value  market_wage_diff
# 2          Neymar Jr  290000.0  118500000.0       118210000.0
# 0           L. Messi  565000.0  110500000.0       109935000.0
# 4       K. De Bruyne  355000.0  102000000.0       101645000.0
# 5          E. Hazard  340000.0   93000000.0        92660000.0
# 15         P. Dybala  205000.0   89000000.0        88795000.0
# ...              ...       ...          ...               ...
# 17539       C. Singh       NaN          NaN               NaN
# 17672       R. Kawai    1000.0          NaN               NaN
# 17726      T. Warner    1000.0          NaN               NaN
# 17752    S. Phillips    1000.0          NaN               NaN
# 18183  K. Pilkington    1000.0          NaN               NaN
#
# [18207 rows x 4 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-abd040e1b6bd> in <module>
# ----> 1 df1.Val = (df1.Val.replace(r'[KMB]+$', '', regex=True).astype(float) * df.Val.str.extract(r'[\d\.]+([KMB]+)', expand=False).fillna(1).replace(['K','M', 'B'], [10**3, 10**6, 10**9]).astype(int))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Val'

# %%
# Out:
#                 Name      Wage        Value  market_wage_diff
# 2          Neymar Jr  290000.0  118500000.0       118210000.0
# 0           L. Messi  565000.0  110500000.0       109935000.0
# 4       K. De Bruyne  355000.0  102000000.0       101645000.0
# 5          E. Hazard  340000.0   93000000.0        92660000.0
# 15         P. Dybala  205000.0   89000000.0        88795000.0
# ...              ...       ...          ...               ...
# 17539       C. Singh       NaN          NaN               NaN
# 17672       R. Kawai    1000.0          NaN               NaN
# 17726      T. Warner    1000.0          NaN               NaN
# 17752    S. Phillips    1000.0          NaN               NaN
# 18183  K. Pilkington    1000.0          NaN               NaN
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
            return float(x.replace('B',''))*10000000
    else:
        return 0.0

wage=df1['Wage'].replace(r'[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace(r'[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Wage']-df1['Value']
df1.sort_values('market_wage_diff',ascending=False)
# Out:
#                 Name      Wage        Value  market_wage_diff
# 2          Neymar Jr  290000.0  118500000.0       118210000.0
# 0           L. Messi  565000.0  110500000.0       109935000.0
# 4       K. De Bruyne  355000.0  102000000.0       101645000.0
# 5          E. Hazard  340000.0   93000000.0        92660000.0
# 15         P. Dybala  205000.0   89000000.0        88795000.0
# ...              ...       ...          ...               ...
# 17539       C. Singh       NaN          NaN               NaN
# 17672       R. Kawai    1000.0          NaN               NaN
# 17726      T. Warner    1000.0          NaN               NaN
# 17752    S. Phillips    1000.0          NaN               NaN
# 18183  K. Pilkington    1000.0          NaN               NaN
#
# [18207 rows x 4 columns]

# %%
# Out:
#                 Name      Wage        Value  market_wage_diff
# 2          Neymar Jr  290000.0  118500000.0       118210000.0
# 0           L. Messi  565000.0  110500000.0       109935000.0
# 4       K. De Bruyne  355000.0  102000000.0       101645000.0
# 5          E. Hazard  340000.0   93000000.0        92660000.0
# 15         P. Dybala  205000.0   89000000.0        88795000.0
# ...              ...       ...          ...               ...
# 17539       C. Singh       NaN          NaN               NaN
# 17672       R. Kawai    1000.0          NaN               NaN
# 17726      T. Warner    1000.0          NaN               NaN
# 17752    S. Phillips    1000.0          NaN               NaN
# 18183  K. Pilkington    1000.0          NaN               NaN
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
            return float(x.replace('B',''))*10000000
    else:
        return 0.0

wage=df1['Wage'].replace(r'[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace(r'[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Wage']-df1['Value']
df1.sort_values('market_wage_diff',ascending=False)
# Out:
#                    Name    Wage    Value  market_wage_diff
# 14759          Yang Jun  2000.0  10000.0           -8000.0
# 17657        J. McCombe  2000.0  10000.0           -8000.0
# 16628  K. Stamatopoulos  1000.0  10000.0           -9000.0
# 15426          M. Tyler  1000.0  10000.0           -9000.0
# 15133         M. Gurski  1000.0  10000.0           -9000.0
# ...                 ...     ...      ...               ...
# 17539          C. Singh     NaN      NaN               NaN
# 17672          R. Kawai  1000.0      NaN               NaN
# 17726         T. Warner  1000.0      NaN               NaN
# 17752       S. Phillips  1000.0      NaN               NaN
# 18183     K. Pilkington  1000.0      NaN               NaN
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
            return float(x.replace('B',''))*10000000
    return 0.0

wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1.sort_values('market_wage_diff',ascending=False)
# Out:
#                 Name      Wage        Value  market_wage_diff
# 2          Neymar Jr  290000.0  118500000.0       118210000.0
# 0           L. Messi  565000.0  110500000.0       109935000.0
# 4       K. De Bruyne  355000.0  102000000.0       101645000.0
# 5          E. Hazard  340000.0   93000000.0        92660000.0
# 15         P. Dybala  205000.0   89000000.0        88795000.0
# ...              ...       ...          ...               ...
# 17539       C. Singh       NaN          NaN               NaN
# 17672       R. Kawai    1000.0          NaN               NaN
# 17726      T. Warner    1000.0          NaN               NaN
# 17752    S. Phillips    1000.0          NaN               NaN
# 18183  K. Pilkington    1000.0          NaN               NaN
#
# [18207 rows x 4 columns]

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
            return float(x.replace('B',''))*10000000
    return 0.0

wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1.sort_values('market_wage_diff',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4265473a9961> in <module>
#      14     return 0.0
#      15
# ---> 16 wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
#      17 value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)
#      18
#
# NameError: name 'df1' is not defined

# %%
import pandas as pd
df=pd.read_csv("./datasets/data.csv")

# %%
df1=df.groupby(['Name','Wage','Value
# Out:
#   File "<ipython-input-10-7cb6ec92b107>", line 1
#     df1=df.groupby(['Name','Wage','Value
#                                         ^
# SyntaxError: EOL while scanning string literal

# %%
df1=df.groupby(['Name','Wage','Value'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-0404256d4a75> in <module>
# ----> 1 df1=df.groupby(['Name','Wage','Value'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ...

# %%
df1=df.groupby(['Name','Wage','Value'])

# %%
df1=pd.Dataframe(df,columns=['Name','Wage','Value'])

# %%
df1

# %%
df1=pd.Dataframe(df,columns=['Name','Wage','Value'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-24d27903a178> in <module>
# ----> 1 df1=pd.Dataframe(df,columns=['Name','Wage','Value'])
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df1=df.Dataframe(df,columns=['Name','Wage','Value'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-707462098495> in <module>
# ----> 1 df1=df.Dataframe(df,columns=['Name','Wage','Value'])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Dataframe'

# %%
df1=pd.Dataframe(df,columns=['Name','Wage','Value'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-24d27903a178> in <module>
# ----> 1 df1=pd.Dataframe(df,columns=['Name','Wage','Value'])
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df1=pd.DataFrame(df,columns=['Name','Wage','Value'])

# %%
df1=pd.DataFrame(df,columns=['Name','Wage','Value'])

# %%
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
def value_to_float(x):
    if type(x)==float or type(x)==int:
        return x
    if 'K' in x:
        if len(x)>1:
            return float(x.replace('K',''))*1000
        return 1000.0
    if 'M' in x:
        if len(x)>1:
            return float(x.replace('M',''))*100000
        return 1000000.0
    if 'B' in x:
            return float(x.replace('B',''))*10000000
    return 0.0

wage=df1['Wage'].replace('[\€]','',regex=True).apply(value_to_float)
value=df1['Value'].replace('[\€]','',regex=True).apply(value_to_float)

df1['Wage']=wage
df1['Value']=value
df1["market_wage_diff"]=df1['Value']-df1['Wage']
df1.sort_values('market_wage_diff',ascending=False)
# Out:
#                Name      Wage       Value  market_wage_diff
# 2         Neymar Jr  290000.0  11850000.0        11560000.0
# 0          L. Messi  565000.0  11050000.0        10485000.0
# 4      K. De Bruyne  355000.0  10200000.0         9845000.0
# 5         E. Hazard  340000.0   9300000.0         8960000.0
# 15        P. Dybala  205000.0   8900000.0         8695000.0
# ...             ...       ...         ...               ...
# 17752   S. Phillips    1000.0         0.0           -1000.0
# 12192  H. Sulaimani    3000.0         0.0           -3000.0
# 3550    S. Nakamura    4000.0         0.0           -4000.0
# 4228       B. Nivet    5000.0         0.0           -5000.0
# 864          Hilton   18000.0         0.0          -18000.0
#
# [18207 rows x 4 columns]

# %%
df2=pd.read_csv("./datasets/players_20.csv")

# %%
df2
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
df3=pd.DataFrame(df2,columns=['short_name','value_eur','wage_eur','released_cause_eur'])

# %%
df3
# Out:
#               short_name  value_eur  wage_eur  released_cause_eur
# 0               L. Messi   95500000    565000                 NaN
# 1      Cristiano Ronaldo   58500000    405000                 NaN
# 2              Neymar Jr  105500000    290000                 NaN
# 3               J. Oblak   77500000    125000                 NaN
# 4              E. Hazard   90000000    470000                 NaN
# ...                  ...        ...       ...                 ...
# 18273         Shao Shuai      40000      2000                 NaN
# 18274       Xiao Mingjie      40000      2000                 NaN
# 18275          Zhang Wei      40000      1000                 NaN
# 18276       Wang Haijian      40000      1000                 NaN
# 18277         Pan Ximing      40000      2000                 NaN
#
# [18278 rows x 4 columns]

# %%
df3=pd.DataFrame(df2,columns=['short_name','value_eur','wage_eur','release_clause_eur'])
df3
# Out:
#               short_name  value_eur  wage_eur  release_clause_eur
# 0               L. Messi   95500000    565000         195800000.0
# 1      Cristiano Ronaldo   58500000    405000          96500000.0
# 2              Neymar Jr  105500000    290000         195200000.0
# 3               J. Oblak   77500000    125000         164700000.0
# 4              E. Hazard   90000000    470000         184500000.0
# ...                  ...        ...       ...                 ...
# 18273         Shao Shuai      40000      2000             70000.0
# 18274       Xiao Mingjie      40000      2000             72000.0
# 18275          Zhang Wei      40000      1000             70000.0
# 18276       Wang Haijian      40000      1000             70000.0
# 18277         Pan Ximing      40000      2000                 NaN
#
# [18278 rows x 4 columns]

# %%
df3=df3.apply(lambda item:  item['release_clause eur']==NaN return item['release_clause eur']=0)
# Out:
#   File "<ipython-input-35-09ad19d88297>", line 1
#     df3=df3.apply(lambda item:  item['release_clause eur']==NaN return item['release_clause eur']=0)
#                                                                 ^
# SyntaxError: invalid syntax

# %%
df3=df3.apply(lambda item:  item['release_clause eur']==NaN  item['release_clause eur']=0)
# Out:
#   File "<ipython-input-37-0f649fb89616>", line 1
#     df3=df3.apply(lambda item:  item['release_clause eur']==NaN  item['release_clause eur']=0)
#                                                                  ^
# SyntaxError: invalid syntax

# %%
df3=df3['release_clause_eur'].apply(lambda item:  item['release_clause_eur']==NaN item['release_clause_eur']=0)
# Out:
#   File "<ipython-input-41-c0f14e9ce559>", line 1
#     df3=df3['release_clause_eur'].apply(lambda item:  item['release_clause_eur']==NaN item['release_clause_eur']=0)
#                                                                                       ^
# SyntaxError: invalid syntax

# %%
release_clause=df2['release_clause_eur'].apply(lambda x:  0 if x=='NaN' else x)

# %%
release_clause
# Out:
# 0        195800000.0
# 1         96500000.0
# 2        195200000.0
# 3        164700000.0
# 4        184500000.0
#             ...
# 18273        70000.0
# 18274        72000.0
# 18275        70000.0
# 18276        70000.0
# 18277            NaN
# Name: release_clause_eur, Length: 18278, dtype: float64

# %%
release_clause=df2['release_clause_eur'].apply(lambda x:  0 if x==NaN else x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-51d23c2135d3> in <module>
# ----> 1 release_clause=df2['release_clause_eur'].apply(lambda x:  0 if x==NaN else x)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-44-51d23c2135d3> in <lambda>(x)
# ----> 1 release_clause=df2['release_clause_eur'].apply(lambda x:  0 if x==NaN else x)
#
# NameError: name 'NaN' is not defined

# %%
release_clause=df2['release_clause_eur'].apply(lambda x:  0 if type(x)==String  'NaN' in x else x)
# Out:
#   File "<ipython-input-47-b9ce7dc098d3>", line 1
#     release_clause=df2['release_clause_eur'].apply(lambda x:  0 if type(x)==String  'NaN' in x else x)
#                                                                                     ^
# SyntaxError: invalid syntax

# %%
release_clause=df2['release_clause_eur'].apply(lambda x: x   if x else 0)
release_clause
# Out:
# 0        195800000.0
# 1         96500000.0
# 2        195200000.0
# 3        164700000.0
# 4        184500000.0
#             ...
# 18273        70000.0
# 18274        72000.0
# 18275        70000.0
# 18276        70000.0
# 18277            NaN
# Name: release_clause_eur, Length: 18278, dtype: float64

# %%
import math as m
release_clause=df2['release_clause_eur'].apply(lambda x:   0 if m.isnan(x) else x)

# %%
df3
# Out:
#               short_name  value_eur  wage_eur  release_clause_eur
# 0               L. Messi   95500000    565000         195800000.0
# 1      Cristiano Ronaldo   58500000    405000          96500000.0
# 2              Neymar Jr  105500000    290000         195200000.0
# 3               J. Oblak   77500000    125000         164700000.0
# 4              E. Hazard   90000000    470000         184500000.0
# ...                  ...        ...       ...                 ...
# 18273         Shao Shuai      40000      2000             70000.0
# 18274       Xiao Mingjie      40000      2000             72000.0
# 18275          Zhang Wei      40000      1000             70000.0
# 18276       Wang Haijian      40000      1000             70000.0
# 18277         Pan Ximing      40000      2000                 0.0
#
# [18278 rows x 4 columns]

# %%
df3.to_csv("./datasets/test.csv")
